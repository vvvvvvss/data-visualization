# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
def function(x, y):
	return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-10, 10, 40)
y = np.linspace(-10, 10, 40)

X, Y = np.meshgrid(x, y)
Z = function(X, Y)

fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection='3d')

ax.plot_surface(X, Y, Z, cmap='cool', alpha=0.8)

ax.set_title('3D Contour Plot', fontsize=14)
ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
ax.set_zlabel('z', fontsize=12)

plt.show()

# %%
import plotly.express as px

# Loading the iris dataset
df = px.data.iris()

fig = px.scatter(df, x="sepal_width", y="sepal_length", title="Scatter Plot",
				color="species", size='petal_length', 
				hover_data=['petal_width'])
fig.show()

# %%
import plotly.express as px

df = px.data.iris()

fig = px.bar(df, x = "sepal_width", y = "sepal_length",title="Bar Plot",color="species")
ax.set_title('Bar Plot', fontsize=14)
fig.show()

# %%
import plotly.express as px 

df = px.data.iris() 

fig = px.histogram(df, x="sepal_width", y ='sepal_length',title="Histogram Plot", color='species') 
fig.show()

# %%
# Loading the iris dataset
df = px.data.iris()

fig = px.pie(df, values="sepal_width", names="species", color="species", title="Pie plot")
fig.show()

# %%
import plotly.express as px

df = px.data.iris()

fig = px.box(df, x="sepal_width", y="sepal_length", color="species", title="Box plot")

fig.show()
